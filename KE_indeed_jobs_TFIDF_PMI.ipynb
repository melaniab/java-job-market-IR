# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
import string
import itertools
import pandas as pd

stopwords = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\melania\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\melania\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def _trees_to_keyphrases(parsed_chunks):
    """
    Helper method to extract keyphrases as space-separated text from the trees of parsed chunks.
    """
    # Convert extracted to flat (CONLL - Begining, Inside, Outside of chunk) format
    chunks2conll = [nltk.chunk.tree2conlltags(_chunk) for _chunk in parsed_chunks]
    
    chunks2groups = [(key, list(group)) for _sent in chunks2conll 
                     for key, group in itertools.groupby(_sent, lambda x : x[2] != 'O')]
    
    # Get only the keyphrases:
    keyphrases = [" ".join(x[0] for x in group) for key, group in chunks2groups if key]
    keyphrases = [_kp for _kp in keyphrases if all(_s not in string.punctuation for _s in _kp)]
    
    return keyphrases
    
    
def select_by_pos_tag(sentences, regexp, verbose=False):
    # POS-tag sentences 
    pos_tagged_sentences = [nltk.pos_tag(_sentence) for _sentence in sentences]
    if verbose: print("1. Pos-tagged sentences: ", pos_tagged_sentences[0])
    
    # Extract chunks matching the regexp from the sentences
    chunker = nltk.chunk.regexp.RegexpParser(regexp)
    sentence_chunks = [chunker.parse(_sentence) for _sentence in pos_tagged_sentences]
    if verbose: print("2. Extracted chunks: ", sentence_chunks[0])
    
    # Extract the keyphrases from the tree format
    candidates = _trees_to_keyphrases(sentence_chunks)
    if verbose: print("3. Extracted keyphrases:", candidates[:10])
    
    return set(candidates)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict, Counter

def score_keyphrases_by_tfidf(texts, candidates, squashing_func=sum):
    vectorizer = TfidfVectorizer(ngram_range=(1,3), vocabulary=candidates)
    train_corpus = vectorizer.fit_transform(texts)
    
    kp_tfidfs = defaultdict(lambda: [])
    for kp in candidates:
        kp_tfidfs[kp] += [train_corpus[0].toarray()[0][vectorizer.vocabulary_[kp]]]
    
    squashed_results = {_kp: squashing_func(_v) for _kp, _v in kp_tfidfs.items()}
    return squashed_results

# %%
#1. TF_IDF for Indeed.com
from nltk.tokenize import TweetTokenizer
tweet_tok = TweetTokenizer()
df = pd.read_csv("indeed - indeed.csv", header = None, names = ["Title", "Text"])
full_text = "\n\n\n\n".join(df['Text'])
sentences = nltk.sent_tokenize(full_text)
token_sentences = [tweet_tok.tokenize(sentence) for sentence in sentences]
print(token_sentences[0:4])
# Out:
# [['Fullstack', 'Java', 'Developer', '(', 'm', '/', 'f', ')', 'gamigo', 'AG-Redwood', 'City', ',', 'CAAbout', 'us', 'The', 'gamigo', 'group', 'is', 'a', 'thriving', 'and', 'fast-growing', 'company', 'within', 'the', 'games', 'market', '.'], ['We', 'have', 'an', 'ample', 'portfolio', 'of', 'online', 'and', 'mobile', 'games', 'at', 'command', ',', 'including', 'a', 'variety', 'of', 'leading', 'MMO', 'role', 'playing', 'and', 'strategy', 'games', '.'], ['Our', 'company', 'focuses', 'primarily', 'on', 'games', 'operations', 'on', 'the', 'European', 'and', 'American', 'market', '.'], ['With', 'millions', 'registered', 'users', 'and', 'a', 'broad', 'range', 'of', 'gaming', 'portals', ',', 'the', 'gamigo', 'group', 'turned', 'into', 'one', 'of', 'the', 'leading', 'gaming', 'providers', '.']]

# %%
grammar = r'KT: {(<NN><NN>|<JJ><NN>|<FW>)}'
candidates = select_by_pos_tag(token_sentences, grammar, verbose=True)
# Out:
# 1. Pos-tagged sentences:  [('Senior', 'JJ'), ('Java', 'NNP'), ('Developer', 'NNP'), ('–', 'NNP'), ('Syncplicity', 'NNP'), ('We', 'PRP'), ('are', 'VBP'), ('searching', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('senior', 'JJ'), ('developer', 'NN'), ('in', 'IN'), ('our', 'PRP$'), ('Java', 'NNP'), ('Syncplicity', 'NNP'), ('team', 'NN'), ('.', '.')]
# 2. Extracted chunks:  (S
#   Senior/JJ
#   Java/NNP
#   Developer/NNP
#   –/NNP
#   Syncplicity/NNP
#   We/PRP
#   are/VBP
#   searching/VBG
#   for/IN
#   a/DT
#   (KT senior/JJ developer/NN)
#   in/IN
#   our/PRP$
#   Java/NNP
#   Syncplicity/NNP
#   team/NN
#   ./.)
# 3. Extracted keyphrases: ['senior developer', 'great opportunity', 'competitive remuneration', 'international company', 'full potential', 'Working time', 'office space', 'various entertainment', 'table tennis', 'Regular team']

# %%
candidates
# Out:
# {'other technology',
#  'item management',
#  'Project leadership',
#  'software system',
#  'parental leave',
#  'Major Market',
#  'skillsStrong understanding',
#  'clear code',
#  'client leadership',
#  'award winning',
#  'career opportunity',
#  'code development',
#  'management information',
#  'new feature',
#  'similar development',
#  'application technology',
#  'high velocity work ethos',
#  'world today',
#  'similar build',
#  'service level',
#  'test design',
#  'edge technology',
#  'distributed system design Exposure',
#  'handson experience',
#  'maintainable Work',
#  'web presentation',
#  'distributed microservice',
#  'agile environment',
#  'detailed unit',
#  'll need',
#  'premier client',
#  'enable client',
#  'monitor software',
#  'own pay',
#  'Direct Hire',
#  'emergency systemsOur',
#  'deferred compensation',
#  'bottom line',
#  'technical mentor',
#  'remote heart',
#  'scrum agile development methodology',
#  'share knowledge',
#  'program access',
#  'dynamic organization',
#  'business consultation',
#  'full service',
#  'willing mentor',
#  'concurrent platform',
#  'technology provider',
#  'process improvement',
#  'dynamic routing',
#  'challenging business',
#  'knowledge preferredJob',
#  'compiler development',
#  'right individualCompensation',
#  'gym membership',
#  'incredible place',
#  'national origin',
#  'website layout',
#  'release management',
#  'digital landscape',
#  'streetMonthly company',
#  'project scope',
#  'daily production',
#  'credit check',
#  'whole self',
#  'music videos',
#  'detailed level',
#  'public assistance',
#  'international work',
#  'superior customer',
#  'efficient performance',
#  'functional specification',
#  'role playing',
#  'market leader',
#  'ideal candidate',
#  'particular security',
#  'customized onboarding',
#  'case basis',
#  'flexible working',
#  'tech lead',
#  'similar field',
#  'complexity estimation',
#  'item automation',
#  'depth knowledge',
#  'new era',
#  'multiple system',
#  'local law',
#  'drive team',
#  'Strong desire',
#  'other team',
#  'impact analysis',
#  'transmission equipment',
#  'information technology',
#  'external design specificationsJob Type',
#  'giant objective',
#  'relational databaseFamiliar',
#  'minimal management supervision EDUCATION',
#  'network routing',
#  'General experience',
#  'application scaling',
#  'high talent',
#  'appropriate translation',
#  'healthy work',
#  'general guidance',
#  'requiredJob Type',
#  'hourContractJob Title',
#  's degreeShould',
#  'spatial data',
#  'scalable software',
#  'engineering field',
#  'modern web',
#  's degree',
#  'possible way',
#  'skill portfolio',
#  'cooperative environment',
#  'complex integration',
#  'global threat',
#  'application integrationJob',
#  'production community',
#  'complex design',
#  'life insurance',
#  'relevant industry',
#  'cutting edge',
#  'mobile app',
#  'code coverage',
#  'mobile device',
#  'qualitative degreeThe',
#  'system architect',
#  'profitable ecommerce',
#  'other reason',
#  'right place',
#  'REQUIRED QUALIFICATIONS',
#  'repositoryJob Type',
#  'equivalent combination',
#  'enterprise level',
#  'primary focus',
#  'collaborative team',
#  'general description',
#  'change agent',
#  'development experience',
#  'background check',
#  'codeo documentationo web application securityo performance',
#  'skillsStrong organization',
#  'annual retreat',
#  'competitive eSport',
#  'independent delivery',
#  'solid grounding',
#  'position number',
#  'articulate communication',
#  'disciplined manner',
#  'Good understanding',
#  'Multiple statesDuration',
#  'mobile game',
#  'code reusability',
#  'full time',
#  'front end',
#  'end client',
#  'related occupation',
#  'robust enterprise',
#  'robust understanding',
#  'technical community',
#  'internal business',
#  'google protobuf',
#  'experience design',
#  'senior member',
#  'architecture understanding',
#  'Critical success',
#  'personal accountability',
#  'development approachesFamiliarity',
#  'independent team',
#  'significant complexity',
#  'open environment',
#  'large population',
#  'engineersLead system',
#  'Direct Experience',
#  'tangible feedback',
#  'Strong expertise',
#  'logical approach',
#  'complex business',
#  'extra mile',
#  'production life',
#  'plusJob Type',
#  'drive content',
#  'acceleration business',
#  'business objectivesDegree',
#  'year java',
#  'fixed income',
#  'business context',
#  'phenomenal coffee',
#  'production ready',
#  'flow diagramming',
#  'new product',
#  'ad impression',
#  'strong expertise',
#  'work ethic',
#  'software reliability',
#  'first letter',
#  'system monitoring',
#  'scrum methodology',
#  'building web',
#  'enterprise development',
#  'efficient use',
#  'core platform',
#  'build automation',
#  'user experience',
#  'top tier',
#  'research project',
#  'signal processing',
#  'business process',
#  'human potential',
#  'transformation —',
#  'experience recommendedExperience',
#  'timely delivery',
#  'Good potential',
#  'patternsExcellent experience',
#  'inclusive team',
#  'political affiliation',
#  'final consideration',
#  'deploymentEffective communication',
#  'keyJob Type',
#  'excellent job',
#  'high degree',
#  'first year',
#  'code refactoring',
#  'great engineering',
#  'supplemental question',
#  'customer adoption',
#  'robust portfolio',
#  'll bring',
#  'preferred staffing',
#  'system risk',
#  'employment Work',
#  'known business',
#  'cloud development',
#  'typesCollection framework',
#  'full interoperability',
#  'successful team',
#  'practical experience',
#  'scalable omnichannel',
#  'configuration control',
#  'lawful alien',
#  'concurrent programming',
#  'profilingo mocking',
#  'world ’',
#  'secure coding',
#  'reliable experience',
#  'cool product',
#  'infrastructure engineering',
#  'logical argument',
#  'operational feasibility',
#  'query optimization',
#  'integration team',
#  'executive level',
#  'functional software',
#  'right answer',
#  'real time vulnerability threat',
#  'good communicator',
#  'Prior experience',
#  'useful unit',
#  'inclusive working',
#  'diverse project',
#  'global asset management firm',
#  'Long TermRate',
#  'None Polygraph',
#  'lead team',
#  'production release',
#  'team player',
#  'othersJob Type',
#  'hybrid approach',
#  'industry standard',
#  'essential component',
#  'project accountability',
#  'patented technology',
#  'music distribution',
#  'environmentRetail',
#  'web collaboration',
#  'performance feedback',
#  'custom class',
#  'regular code',
#  'interim business',
#  'research staff',
#  'weekly game',
#  'team atmosphereExperience',
#  'backend exposure',
#  'integrated system',
#  'multiple platform',
#  'message bus',
#  'language Experience',
#  'weekly status',
#  'digital transformation consulting firm',
#  'uptime environment',
#  'office kitchen',
#  'eCommerce experience',
#  'core java',
#  'past please',
#  'production support',
#  'professional way',
#  'sophisticated design',
#  'rapid development',
#  'continuous integration',
#  'global pay',
#  'compensation package',
#  'spring framework',
#  'online experience',
#  'senior team',
#  'Retail domain',
#  'protected veteran',
#  'undue hardship',
#  'building responsive',
#  'corporate environment',
#  'architectural development',
#  'current chat',
#  'handle conflict',
#  'database management',
#  'necessaryDocument work',
#  'tech company',
#  'central role',
#  'life balance',
#  'development methodology',
#  'reusable code',
#  'solid development',
#  'source control',
#  'spread opportunity',
#  'plus Passion',
#  'current role',
#  'report jobIf',
#  'single step',
#  'software product',
#  'drive resolution',
#  'middleware java',
#  'instructional material',
#  'track drive',
#  'featuresJob Type',
#  'Excellent attention',
#  'direct supervisor',
#  'save job',
#  'server scripting',
#  'mutual understanding',
#  'positive impact',
#  'upward interaction',
#  'search engine',
#  'technical field',
#  'automated unit',
#  'document engineering',
#  'deep expertise',
#  'data modeling',
#  'multibillion dollar',
#  'code version',
#  'assetJob Type',
#  'educational software',
#  'digital journeys',
#  'essential job',
#  'dependable individual',
#  'several host',
#  'work environment',
#  'other manner',
#  'use shell',
#  'technology infrastructure',
#  'complete software development life',
#  'jboss web',
#  'networking environment',
#  'retirement program',
#  'talented software',
#  'report job',
#  'agile engineering',
#  'key technology',
#  'full EEO policy statement',
#  'team – strong communication',
#  'stack developer',
#  'senior level',
#  'future use',
#  'status quo',
#  'job application',
#  'unique client',
#  'software engineeringexperience',
#  'debug software',
#  'explosive growth',
#  'company methodology',
#  'networking experience',
#  'conceptual foundation',
#  'scrum development',
#  'peak season',
#  'distributed platform',
#  'small group',
#  'schema design',
#  'healthy snack',
#  'individual contributor',
#  'deep industry',
#  'quality software',
#  'key role',
#  'data migration',
#  'company culture',
#  'visa status',
#  'digital career',
#  'personal merit',
#  'developmentJob Type',
#  'experience building',
#  'full spectrum',
#  'good programming',
#  'scanner maintenance',
#  'premier technology',
#  'way communication',
#  'development technology',
#  'software engineering experienceReal passion',
#  'functional analysis',
#  'functional area',
#  'scalable web',
#  'protected status',
#  'modular code',
#  'Primary Location',
#  'daily basis',
#  'implement web application system',
#  'full ownership',
#  'complex implementation',
#  'outstanding talent',
#  'enterprise class management platform',
#  'immediate hire',
#  'technical stack',
#  'Basic knowledge',
#  'fundamental belief',
#  'service dev',
#  'organization reputation',
#  'strategic direction',
#  'conduct root cause analysisExperience',
#  'integrated support',
#  'progressive experience',
#  'sensor development',
#  'changing world',
#  'other design',
#  'code coverageExperience',
#  'androbust workforce',
#  'user behavior',
#  'Net set',
#  'other legacy',
#  'music industry',
#  'diverse culture',
#  'Production Support',
#  'good team',
#  'have experience',
#  'project business',
#  'job content',
#  'computer language',
#  'human discovery',
#  'project development',
#  'experience developing',
#  'java developer',
#  'test automation',
#  'business world',
#  'Enhance performance',
#  'frequent refactoring',
#  'affiliated Accenture',
#  'cloud management',
#  'project lifecycle',
#  'distribution partner',
#  'Strong background',
#  'integrated business',
#  'financial experience',
#  'developer wanting',
#  'extreme pressure',
#  'enterprise integration',
#  'year Work',
#  'portal development',
#  'issue resolution',
#  'customer facing',
#  'occasional guidance',
#  'high impact',
#  'programming experience',
#  'backend application',
#  'candidate include',
#  'broad understanding',
#  'Secret clearance',
#  'report delivery',
#  'familiarity building modern Spring',
#  'modern software',
#  'statistical modeling',
#  'Extraordinary communication',
#  'mentor client',
#  'Position Description',
#  'Solid experience',
#  'met',
#  'team environment',
#  'client application development professionalPosition',
#  'database skill',
#  'retirement plan',
#  'telecommunications infrastructure',
#  'system performance',
#  'active account',
#  'simple software',
#  'appropriate depth',
#  'production item',
#  'system documentation',
#  'Solid foundation',
#  'strong coding',
#  'tech experience',
#  'layered security',
#  'Regular Work',
#  'fun room',
#  'light rail',
#  'solid growth',
#  'previous experience',
#  'core tutoring',
#  'employee wellness',
#  'technology environmentMinimum',
#  'global ad',
#  'casual dress',
#  'collaborative work',
#  'average rate',
#  'employer sponsorship',
#  'equal employment',
#  'entire software development life',
#  'lab environment',
#  'testable quality',
#  '’ experience',
#  'technical knowledge',
#  'independent security software company',
#  'major product',
#  'global foundation',
#  'business unit',
#  'wide range',
#  'complex project',
#  'align workload',
#  'problem diagnosis',
#  'genomic workflow',
#  'relevant experience',
#  'agile product',
#  'professional experience',
#  'awesome product',
#  'Experience developing',
#  'center infrastructure',
#  'strong understanding',
#  'shell scripting',
#  'implement program',
#  'right individual',
#  'above configuration',
#  'general debugging',
#  'high standard',
#  'flexible work',
#  'spring cloud',
#  'advanced schema',
#  'cover letter',
#  'significant experience',
#  'different application',
#  'exceptional communication',
#  'full implementation',
#  'asset allocation',
#  'national resource',
#  'JavaInternal Role',
#  'key requirement',
#  'top technology',
#  'real time',
#  'iOS apps',
#  'lucrative career',
#  'general nature',
#  'oral communication',
#  'Send resume',
#  'position description',
#  'red tape',
#  'productive member',
#  'strong ability',
#  'significant contributor',
#  'proven track',
#  'basic testing',
#  'agile delivery',
#  'full web',
#  'job number',
#  'critical role',
#  'technology company',
#  'Year experience',
#  'document software',
#  'performance management',
#  'global engineering',
#  'revenue cycle',
#  'mobile software',
#  'large scale',
#  'right candidate',
#  'high throughput',
#  'possible extension',
#  'employee assistance',
#  'monthsJob Description',
#  'full address',
#  'strong experience',
#  'technical work',
#  'unique perspective',
#  'small fast',
#  'financial risk',
#  'Clear understanding',
#  'dynamic environmentGood',
#  'overall project',
#  'senior staff',
#  'code script',
#  'peer review',
#  'maintain software',
#  'year college',
#  'enterprise environmentMust',
#  'private equity',
#  'integrated suite',
#  'government transformation',
#  'continuous improvement',
#  'work experience',
#  'Experience designing',
#  'client server',
#  'yearContract Renewal',
#  'American market',
#  'rapid proto type development',
#  'system design',
#  'basic cryptography',
#  'lifecycle development',
#  'proactive leadership',
#  'data architecture',
#  'effective support',
#  'NoContract Length',
#  'technical leadership',
#  'common goal',
#  'curriculum development',
#  'interface specs',
#  'possible start',
#  'Excellent communicator',
#  'Excellent problem',
#  'modern build',
#  'effective cutting edge design',
#  'ie testing',
#  'quality review',
#  'order capturing',
#  'core team',
#  'enterprise software',
#  'security investigation',
#  'large enterprise',
#  'various experience',
#  'application scaleExperience',
#  'quality assurance',
#  'Solid understanding',
#  'manage multiple',
#  'technical contributor',
#  'ambitious project',
#  'exciting endeavor',
#  'insatiable drive',
#  'junior product',
#  'job description',
#  'requisition number',
#  'strategic optimization',
#  'technical discipline',
#  'development process',
#  'message lag',
#  'excellent member',
#  'industry grade',
#  'technical perspective',
#  'message processingFamiliarity',
#  'Employment Type',
#  'Solid computer',
#  'email spam',
#  'functional code',
#  'free training',
#  '· Experience',
#  'job performance',
#  'applicable work',
#  'new software',
#  'Java DeveloperLocation',
#  'time position',
#  'Excellent knowledge',
#  'regular development',
#  'enterprise cloud',
#  'distributed structure',
#  'development effort',
#  'application scale',
#  'occasional walking',
#  'preferred candidate',
#  'technical design',
#  'citizen status',
#  'different system',
#  'implement efficient',
#  'outstanding service',
#  'Preferred Experience',
#  'sick leave',
#  'project time',
#  'energetic company',
#  'application access',
#  'software code',
#  'messaging service',
#  'billable bonus',
#  'accredited institution',
#  'diverse solution',
#  'online help',
#  'excellent communication',
#  'sustainable value',
#  'same way',
#  'necessaryDemonstrate correctness',
#  'automation software',
#  'back end',
#  'enterprise class',
#  'speech recognition',
#  'development teamsAnalyze',
#  'annual bonus',
#  'source code',
#  'passionate technologist',
#  'professional work',
#  'global professional',
#  'field mapping',
#  'world class',
#  'employment consistent',
#  'technical training',
#  'significant cloud',
#  'direct experience',
#  'plus Experience',
#  'mongo db',
#  'unsolicited headhunter',
#  'release schedule',
#  'entire duration',
#  'competitive compensation',
#  'international team',
#  'diverse set',
#  'small part',
#  'Encourage code',
#  'critical analysis',
#  'database development',
#  'efficient entity',
#  'product code',
#  'high bar',
#  'software quality',
#  'customer support',
#  'risk assessment',
#  'open communication',
#  'exceptional talent',
#  'automated testing',
#  'integration toolsExperience',
#  'great custom',
#  'business day',
#  'specific assignment',
#  'software environment',
#  'definite plus',
#  'maintainable solution',
#  'cloud platformDevelop',
#  'technical debt',
#  'untapped market',
#  'core language',
#  'performance tuning',
#  'level proficiency',
#  'development center',
#  'interested candidate',
#  'party access',
#  'drive development',
#  'new company',
#  'implement unit',
#  'travel coverage',
#  'network planning',
#  'code base',
#  'building event',
#  'appropriate development',
#  'information security',
#  'work break',
#  'equal opportunity',
#  'new application',
#  'big picture',
#  'depth understanding',
#  'creative thinking',
#  's technology',
#  'Last Name',
#  'essential role',
#  'ambitious problem',
#  'Java',
#  'next generation',
#  'circuit design',
#  'computer audio',
#  'escalation point',
#  'additional office',
#  'trusted view',
#  'full application',
#  'digital maturity',
#  'optimal combination',
#  'execute unit',
#  'unique layer',
#  'integration test',
#  'correct software',
#  'fun work',
#  'qualitative research',
#  'design Experience',
#  'comprehensive portfolio',
#  'standard software',
#  'mobile application',
#  'ContractWork authorization',
#  'overall system',
#  'green card',
#  'basic web',
#  'business requirement',
#  'disruptive technology',
#  'other serverless technologiesJob Type',
#  'Work Authorization',
#  'software stack',
#  'mustSound knowledge',
#  'customer success',
#  'immediate team',
#  'database tuning',
#  'overall experience',
#  'US government',
#  'unparalleled adaptability',
#  'dependency injection',
#  'system impact',
#  'consuming web',
#  'implement restful',
#  'human capital management time',
#  'hourContractJob SummaryRole',
#  'social networking',
#  'internal team',
#  'industry experience',
#  'bound coverage',
#  'cloud platform',
#  'knowledge onSoftware',
#  'content management',
#  'distributed team',
#  'new marketplace',
#  'sick time',
#  'solution development',
#  'mental disability',
#  'building software',
#  'serious street',
#  'related discipline',
#  'concerted level',
#  'integral part',
#  'innovative software development support',
#  'community involvement',
#  'Strong organization',
#  'appropriate recruiter',
#  'web application',
#  'software design',
#  'leadership role',
#  'Strong sense',
#  'product roadmap',
#  's business',
#  'business domain',
#  'conditionsJob Type',
#  'dental insurance',
#  'application stack',
#  'industry research',
#  'complex web',
#  'primary responsibility',
#  'end DeveloperPosition',
#  'clustered server',
#  'eCommerce development',
#  'engineering language',
#  'referential integrity',
#  'particular position',
#  'bar code',
#  'client experience',
#  'entire development',
#  'following link',
#  'innovative technology',
#  'positive culture',
#  'agile methodology',
#  'equivalent education',
#  'high level design documentation',
#  'hybrid cloud',
#  'complex sql',
#  'complete list',
#  'innovative hardware',
#  'neededJob Type',
#  'code developedJob',
#  'plusThe job',
#  'plusExperience building',
#  'good research',
#  'Strong understanding',
#  'parent company',
#  'large integration',
#  'forward thinking',
#  'production environment',
#  'design documentation',
#  'compliant app',
#  'proven ability',
#  'designand development',
#  'customer issue',
#  'strong database',
#  'flexible business',
#  'revolutionary iOS',
#  'global economy',
#  'application code',
#  'job knowledge',
#  'cloud consumption',
#  'platform Expertise',
#  'integrated development',
#  'architect level',
#  'multinational technology',
#  'finance domain',
#  'aspiration –',
#  'document platform',
#  'wide variety',
#  'entrepreneurial attitude',
#  's mission',
#  'online content',
#  'code versioning',
#  'professional growth',
#  'various programming',
#  'smart retail',
#  'scanner business',
#  'advanced programming',
#  'significant depth',
#  'software craftsmanship',
#  'implemented functionality',
#  'intimate knowledge',
#  'established leader',
#  'significant direction',
#  'corporate umbrella',
#  'global team',
#  'enterprise risk',
#  'class ”',
#  'congestion control',
#  'java stack',
#  'data usage',
#  '“ intent',
#  'first day',
#  'ambitious goal',
#  'insuranceDental insuranceOther',
#  'release process',
#  'level code',
#  'customer engagement',
#  'entire breadth',
#  'equivalent experience',
#  'environmentJob',
#  'reliable code',
#  'physical program',
#  'amazing pace',
#  'financial information',
#  'comprehensive documentation',
#  'technical specs',
#  'impactful IT',
#  'complex modernization',
#  'smart protection',
#  'entire organization',
#  'comparable experience',
#  'digital experience',
#  'tuition reimbursement',
#  'strong communication',
#  'casual work',
#  'detailed design',
#  'year heritage',
#  'll feel',
#  'Elastic search',
#  'great opportunity',
#  'decision maker',
#  'eligible list',
#  'technical lead',
#  'design patternExcellent',
#  'phonetic filtersUnderstanding',
#  'technical architecture',
#  'pioneering spirit',
#  'occasional travelingDT',
#  'delivery team',
#  'Trading Policy',
#  'immediate impact',
#  'activitiesImplement automation',
#  'low latency',
#  'high availabilityExperience',
#  'talented team',
#  'productive development',
#  'software performance',
#  'complex engineering',
#  'strong desire',
#  'other programming',
#  'foster equality',
#  'internal engineer',
#  'configurable component',
#  'business rulesExperience',
#  'Agile process',
#  'technical release',
#  'functional capability',
#  'technology platform',
#  'self starter',
#  'advanced degree',
#  'contact information',
#  'problem resolution',
#  'collaborative role',
#  'exception handling',
#  'minimum guidance',
#  'inclusive workforce',
#  'product team',
#  'protected class',
#  'old custom',
#  'idyllic location',
#  'performance tuningAbility',
#  'unique opportunity',
#  'implementationDisciplined approach',
#  'update resume',
#  'healthier atmosphere',
#  'similar career',
#  'bug tracking',
#  'evolving world',
#  'site reliability',
#  'diverse workforce',
#  'high end',
#  'management Experience',
#  'recent growth',
#  'responsive web',
#  'Technical leadership',
#  'database Experience',
#  'senior engineer',
#  'QA function',
#  'everything –',
#  'retail experience',
#  'release pipeline',
#  'scalable application',
#  'analysis Experience',
#  'mobile development',
#  ...}

# %%
#Getting TF-IDF scores 
documents = df['Text']
kp_tfidfs = score_keyphrases_by_tfidf(documents, candidates)
Counter(kp_tfidfs).most_common(35)
# Out:
# [('close collaboration', 0.3356977535618584),
#  ('gamigo group', 0.3356977535618584),
#  ('role playing', 0.1678488767809292),
#  ('office kitchen', 0.1678488767809292),
#  ('single step', 0.1678488767809292),
#  ('strategic optimization', 0.1678488767809292),
#  ('functional code', 0.1678488767809292),
#  ('energetic company', 0.1678488767809292),
#  ('international team', 0.1678488767809292),
#  ('commercial use', 0.1678488767809292),
#  ('follow lean', 0.1678488767809292),
#  ('account system', 0.1678488767809292),
#  ('ample portfolio', 0.1678488767809292),
#  ('major technology', 0.1678488767809292),
#  ('production platform', 0.1678488767809292),
#  ('practical experience', 0.156587570211699),
#  ('platform team', 0.156587570211699),
#  ('web architecture', 0.156587570211699),
#  ('dynamic work', 0.156587570211699),
#  ('experienced engineer', 0.156587570211699),
#  ('broad range', 0.1373362394762297),
#  ('health care', 0.1373362394762297),
#  ('share knowledge', 0.1330548894200199),
#  ('strong background', 0.1330548894200199),
#  ('technical expertise', 0.1330548894200199),
#  ('fast growing', 0.1330548894200199),
#  ('agile environment', 0.1231486710822744),
#  ('good knowledge', 0.1231486710822744),
#  ('life balance', 0.12050154526927195),
#  ('relevant experience', 0.12050154526927195),
#  ('work life', 0.1158618186357975),
#  ('spring hibernate', 0.11009488457452124),
#  ('ideal candidate', 0.10682360217153018),
#  ('work environment', 0.10682360217153018),
#  ('development process', 0.10682360217153018)]

# %%
scores = [('close collaboration', 0.3356977535618584),
 ('gamigo group', 0.3356977535618584),
 ('role playing', 0.1678488767809292),
 ('office kitchen', 0.1678488767809292),
 ('single step', 0.1678488767809292),
 ('strategic optimization', 0.1678488767809292),
 ('functional code', 0.1678488767809292),
 ('energetic company', 0.1678488767809292),
 ('international team', 0.1678488767809292),
 ('commercial use', 0.1678488767809292),
 ('follow lean', 0.1678488767809292),
 ('account system', 0.1678488767809292),
 ('ample portfolio', 0.1678488767809292),
 ('major technology', 0.1678488767809292),
 ('production platform', 0.1678488767809292),
 ('practical experience', 0.156587570211699),
 ('platform team', 0.156587570211699),
 ('web architecture', 0.156587570211699)]
pd.DataFrame(scores)
# Out:
#                          0         1
# 0      close collaboration  0.335698
# 1             gamigo group  0.335698
# 2             role playing  0.167849
# 3           office kitchen  0.167849
# 4              single step  0.167849
# 5   strategic optimization  0.167849
# 6          functional code  0.167849
# 7        energetic company  0.167849
# 8       international team  0.167849
# 9           commercial use  0.167849
# 10             follow lean  0.167849
# 11          account system  0.167849
# 12         ample portfolio  0.167849
# 13        major technology  0.167849
# 14     production platform  0.167849
# 15    practical experience  0.156588
# 16           platform team  0.156588
# 17        web architecture  0.156588

# %%
#2. JObs.bg
df_jobs = pd.read_csv("jobsbg_javaInTitle.csv", header = None, names = ["Title", "Text"])
full_text = "\n\n\n\n".join(df_jobs['Text'])
sentences = nltk.sent_tokenize(full_text)
token_sentences = [tweet_tok.tokenize(sentence) for sentence in sentences]
print(token_sentences[0:4])
# Out:
# [['Senior', 'Java', 'Developer', '–', 'Syncplicity', 'We', 'are', 'searching', 'for', 'a', 'senior', 'developer', 'in', 'our', 'Java', 'Syncplicity', 'team', '.'], ['This', 'team', 'is', 'responsible', 'for', 'Java', '/', 'Linux', 'based', 'cloud', 'micro-services', 'and', 'on-premises', 'connectors', 'that', 'extend', 'the', 'capabilities', 'of', 'the', 'Syncplicity', 'SaaS', 'offering', '.'], ['Working', 'in', 'the', 'Syncplicity', 'team', 'gives', 'you', 'a', 'great', 'opportunity', 'to', 'learn', 'some', 'of', 'the', 'latest', 'in', 'Java', ',', 'Linux', ',', 'AWS', ',', 'security', 'and', 'deployment', 'technologies', 'to', 'advance', 'your', 'skills', 'and', 'career', '.'], ['I', 'have', 'the', 'luxury', 'to', 'work', 'with', 'young', 'and', 'very', 'talented', 'people', '.']]

# %%
grammar = r'KT: {(<NN><NN>|<JJ><NN>|<FW>)}'
candidates = select_by_pos_tag(token_sentences, grammar, verbose=True)
# Out:
# 1. Pos-tagged sentences:  [('Senior', 'JJ'), ('Java', 'NNP'), ('Developer', 'NNP'), ('–', 'NNP'), ('Syncplicity', 'NNP'), ('We', 'PRP'), ('are', 'VBP'), ('searching', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('senior', 'JJ'), ('developer', 'NN'), ('in', 'IN'), ('our', 'PRP$'), ('Java', 'NNP'), ('Syncplicity', 'NNP'), ('team', 'NN'), ('.', '.')]
# 2. Extracted chunks:  (S
#   Senior/JJ
#   Java/NNP
#   Developer/NNP
#   –/NNP
#   Syncplicity/NNP
#   We/PRP
#   are/VBP
#   searching/VBG
#   for/IN
#   a/DT
#   (KT senior/JJ developer/NN)
#   in/IN
#   our/PRP$
#   Java/NNP
#   Syncplicity/NNP
#   team/NN
#   ./.)
# 3. Extracted keyphrases: ['senior developer', 'great opportunity', 'competitive remuneration', 'international company', 'full potential', 'Working time', 'office space', 'various entertainment', 'table tennis', 'Regular team']

# %%
candidates
# Out:
# {'increased demand',
#  'virtual replication',
#  'new business',
#  'Atlassian apps',
#  'particular department',
#  'clear code',
#  'die wir',
#  'career opportunity',
#  'united team',
#  'encouraging work',
#  'subject line',
#  'project domain',
#  'salary –',
#  'driven organization',
#  'sunny office',
#  'single thing',
#  'regional skill',
#  'assume responsibility',
#  'electronic book',
#  'customer portfolio',
#  'following software',
#  'consumer credit',
#  'collegiate manner',
#  'commercial system',
#  'new team',
#  'international distribution',
#  'global product',
#  'висше образование',
#  'good command',
#  'share knowledge',
#  'Good level',
#  'multinational working',
#  'career enhancement',
#  'reference code',
#  'dynamic team',
#  'due consideration',
#  'professional agenda',
#  'global community',
#  'English communication',
#  'present client',
#  'related subject',
#  'scrum team',
#  'national origin',
#  'central platform',
#  'working environment',
#  'graph database',
#  'sneak peek',
#  'international work',
#  'Good interpersonal',
#  'core development',
#  'certification program',
#  'product planning',
#  'market leader',
#  'code integrity',
#  'ideal candidate',
#  'nosql database',
#  'government website',
#  'flexible working',
#  'active part',
#  'continued business',
#  'depth knowledge',
#  'immediate funding',
#  'other team',
#  'good level',
#  'environmental field',
#  'top priority',
#  'wir dir zusätzlich zu deinem neuen',
#  'Attractive compensation',
#  'large data',
#  'enablement initiative',
#  'full suite',
#  'environment •',
#  'nice attitude',
#  'modern web',
#  'card option',
#  'possible way',
#  'einer der',
#  'financial institution',
#  'good spoken',
#  'life insurance',
#  'multithreaded application',
#  'world Work',
#  'multinational team',
#  'many industry',
#  'job interesting',
#  'automotive background',
#  'right place',
#  'rapid growth',
#  'available solution',
#  'experienced professional',
#  'development experience',
#  'smart decision',
#  'good abstraction',
#  'similar •',
#  'big customer',
#  'talent arena',
#  'Good understanding',
#  'full time',
#  'end client',
#  'front end',
#  'Extensive knowledge',
#  'related certificate',
#  'mobile apps',
#  'trusted recruitment',
#  'substantial knowledge',
#  'other form',
#  'enable Smule',
#  'probation period',
#  'Bachelor ’',
#  'senior member',
#  'independent certification',
#  'multinational group',
#  'business analysis',
#  'challenging workplace',
#  'home office',
#  '– coding',
#  'permanent license',
#  'sensitive ’',
#  'developed software',
#  'vorzugsweise der',
#  'complex business',
#  'own choice',
#  'cloud service',
#  'recruitment selection',
#  'service framework',
#  'join eLando',
#  'individual ’',
#  'person program',
#  'private pilot',
#  'various range',
#  'user experience',
#  'robust design',
#  'concrete implementation',
#  'business process',
#  'regular performance',
#  'become part',
#  'systematic analysis',
#  'following OS',
#  'significant latitude',
#  'lead development',
#  'development group',
#  'functional design',
#  'first year',
#  'home option',
#  'Regular company',
#  'big broadcast satellite service',
#  'strong advantage',
#  'practical experience',
#  'intrapreneurial culture',
#  '✔ Experience',
#  'term commitment',
#  'world ’',
#  'partner network',
#  'related documentation',
#  'Basic experience',
#  'following project',
#  'modern technology',
#  'strengthen security',
#  'training plan',
#  'test strategy',
#  'main project',
#  'flat hierarchy',
#  'expert advice',
#  'Всички данни',
#  'good communicator',
#  'offshore division',
#  'Continued learning',
#  'Strong knowledge',
#  'skilled staff',
#  'routine maintenance',
#  'management easy',
#  'team player',
#  'software process',
#  'organic succession',
#  'industry standard',
#  'Critical thinking',
#  'oder einer',
#  'web business',
#  'valuable experience',
#  'art hardware',
#  'full support',
#  'first customer',
#  'yoga room',
#  'communication excellence',
#  'disaster recovery',
#  'new functionality',
#  'wachsen weiter',
#  'basic knowledge',
#  'complex multiline',
#  'innovative way',
#  'additional vacation',
#  'poker tournament',
#  'business system',
#  'eCommerce experience',
#  'sophisticated design',
#  'continuous integration',
#  'compensation package',
#  'hour window',
#  'restart TV',
#  'team building',
#  'network infrastructure',
#  'development methodology',
#  'comfortable office',
#  'reusable code',
#  '\xad tolerance',
#  'source control',
#  'team •',
#  'casino content',
#  'software product',
#  'single day',
#  'internal methodology',
#  'und deinen',
#  'lead role',
#  'technical field',
#  'external business',
#  'green place',
#  'digital insurance software firm',
#  'deep expertise',
#  'work environment',
#  'talented professional',
#  'real relation',
#  'full confidentiality',
#  'Lead architecture',
#  'system development',
#  'aggressive environment',
#  'talented software',
#  'seasonal change',
#  'personal achievement',
#  'key technology',
#  'entire software development process',
#  'main programming',
#  'past year',
#  'public software',
#  'substantial remuneration',
#  'Professional experience',
#  'medical package',
#  'product lifecycle',
#  'senior level',
#  'future use',
#  'development speed',
#  'etc •',
#  'sichern dir',
#  'high growth',
#  'structured code',
#  'multiple fun',
#  'product life',
#  'frequent production',
#  'innovative online',
#  'deep industry',
#  'quality software',
#  'key role',
#  'advanced business',
#  'technical focus',
#  'knowledge base',
#  'dream career',
#  'significant presence',
#  'first level',
#  'base technology',
#  'daily basis',
#  'new office',
#  'recruitment agency',
#  'hybrid framework',
#  'local database',
#  'comprehensive transport management system',
#  'confident developer',
#  'excellent career',
#  'own mobile',
#  'business environment',
#  'close mentorship',
#  'strong integrity',
#  'social graph',
#  'experimental methodology',
#  'symbiotic relationship',
#  'electrical engineering',
#  'personal information',
#  't hesitate',
#  'complete development lifecycle –',
#  'experienced team',
#  'exciting industry',
#  'Social package',
#  'good team',
#  'service learning',
#  'medical program',
#  'extensive knowledge',
#  'right match',
#  'java developer',
#  'test automation',
#  'recent expansion',
#  'tech park',
#  'infrastructure virtualization',
#  'strict confidentiality',
#  'insurance industry',
#  'large hotel',
#  'und zusätzliche',
#  'other data',
#  'professional team',
#  'remote team',
#  'public transportation',
#  'release building',
#  'peak traffic',
#  'right person',
#  'social package',
#  'Solid experience',
#  'team environment',
#  'workflow design',
#  'excellent ability',
#  'system performance',
#  'innovative recruitment',
#  'Unique opportunity',
#  'Personal responsibility',
#  'worldwide leader',
#  'plus •',
#  'beverage program',
#  'scrum master',
#  'interactive web',
#  'correct understanding',
#  'specification review',
#  'recreational area',
#  'collaborative work',
#  'automation platform',
#  'current middleware',
#  'extra dental',
#  '’ experience',
#  'international aviation software company',
#  'integrating custom',
#  'wide range',
#  'system upgrade',
#  'Company management',
#  'relevant experience',
#  'добри условия',
#  'foreign team',
#  'team lead',
#  'professional experience',
#  'außerdem helfen',
#  'development Interaction',
#  'und der',
#  'diverse career',
#  'system build',
#  '” procedure',
#  'server development',
#  'transitional period',
#  'city center',
#  'cover letter',
#  'soft skill',
#  'team size',
#  'development documentation',
#  'real time',
#  'recruiting process',
#  'friendly work',
#  'large code',
#  'strong ability',
#  'proven track',
#  'heterogeneous environment',
#  'service outsourcing',
#  'occasional travelling',
#  'end development',
#  'quality engineering',
#  'technology company',
#  'Team player',
#  'matching storage',
#  'Отлично възнаграждение',
#  'exciting environment',
#  'network io',
#  'right candidate',
#  'large scale',
#  'various cloud',
#  'high throughput',
#  'clear feedback',
#  '•',
#  'technical work',
#  'scale internet',
#  'ad hoc',
#  'stable presence',
#  'Positive attitude',
#  'apps ⇨',
#  'week home',
#  'Free course',
#  'maintain software',
#  'device software',
#  'private equity',
#  'continuous improvement',
#  'fruitful environment',
#  'Permanent employment',
#  'development lab',
#  'typical corporative',
#  'friendly environment',
#  'cloud solution development Experience',
#  'proactive person',
#  'public blockchain',
#  'projectsWe create custom software',
#  'technical leadership',
#  'personal work',
#  'Regular team',
#  'Convenient office',
#  'global provider',
#  'enterprise software',
#  'pair programming',
#  'large enterprise',
#  'various experience',
#  'tested code',
#  'quality assurance',
#  'various business',
#  '⦿',
#  'independent operation',
#  'global gaming',
#  'development process',
#  'friendly culture',
#  'direct collaboration',
#  'week exchange',
#  's future',
#  'academic study',
#  'free training',
#  '· Experience',
#  'new software',
#  'job opportunity',
#  'other perks',
#  'Excellent knowledge',
#  'mobile handheld',
#  'financial budget',
#  'classic enterprise',
#  'ideal applicant',
#  'individual career',
#  'Опит като',
#  'local investor',
#  'occasional work',
#  'professional qualification',
#  'major developer',
#  'technical design',
#  'company manage',
#  'du mit',
#  'Интервю процес',
#  'office location',
#  'energy sector',
#  'sustainable value',
#  'good software',
#  'back end',
#  'annual bonus',
#  'source code',
#  'professional work',
#  'full software development life',
#  'global environment',
#  'global professional',
#  'world class',
#  'international software development company',
#  'technical training',
#  'analytical mindset',
#  'Friendly work',
#  'logical problem',
#  'various entertainment',
#  'relaxed environment',
#  'machine learning',
#  'personal data',
#  'international team',
#  'competitive compensation',
#  'database development',
#  'customer support',
#  'customer ’',
#  'open communication',
#  'international consultancy',
#  'successful business',
#  'right talent',
#  'future generation',
#  'daily remote',
#  'academic record',
#  'great service',
#  '· Passion',
#  'development center',
#  'operational efficiency',
#  'prior experience',
#  'open position',
#  'smartphone user',
#  '• Spring',
#  'great advantage',
#  'practical manner',
#  'code base',
#  'enterprise storage',
#  'office space',
#  'project performance',
#  'base product',
#  'equal opportunity',
#  'sustainable job',
#  'complex workload',
#  'process guidance',
#  'risk analysis',
#  'successful implement',
#  'sprint review',
#  'creative thinking',
#  's technology',
#  'innovative company',
#  'next generation',
#  'strong combination',
#  'satisfactory remuneration',
#  'fitness gym',
#  'partner team',
#  'Open communication',
#  'integration test',
#  'active involvement',
#  'mobile application',
#  'working approach',
#  'career planning',
#  'regular team',
#  'gern mit',
#  'document processing',
#  'Attractive remuneration',
#  'new algorithms',
#  'scary reliability',
#  'local loan',
#  'other message',
#  'cloud platform',
#  'friendly atmosphere',
#  'content management',
#  'complex programming',
#  'building software',
#  'challenging job',
#  'solid software development experience',
#  'Continuous investment',
#  'head office',
#  'business delivery',
#  'да разполага',
#  'web application',
#  'software design',
#  'unique expertise',
#  'optimised software',
#  'remuneration package',
#  'ethical approach',
#  'rich internet',
#  'crisp definition',
#  '“ leader',
#  'responsive attention',
#  'solid understanding',
#  'client experience',
#  'big advantage',
#  'regular contact',
#  'financial modelling',
#  'auf deine',
#  'quick learner',
#  'Annual performance',
#  'equivalent education',
#  'eine vergleichbare',
#  'personal performance',
#  'strong demand',
#  'exciting journey',
#  'Strong understanding',
#  'impactful team',
#  'valuable contribution',
#  'considerable prowess',
#  'competitive pay',
#  'different web',
#  'exciting time',
#  'production environment',
#  'real flair',
#  'great success',
#  'French software',
#  'Bulgarian system',
#  'creative atmosphere',
#  'public sector',
#  'Good database',
#  'music landscape',
#  'innovative customer',
#  'demonstrable experience',
#  'innovative decision',
#  'equivalent •',
#  'technologiesAn advantage',
#  'multinational company',
#  'global company',
#  'wide variety',
#  'modern building',
#  'automotive sector',
#  'professional growth',
#  'dynamic software',
#  '• Work',
#  'technical feasibility',
#  'network administration',
#  'regular basis',
#  'mobile iPhone',
#  'true market',
#  'top quality',
#  'Contract type',
#  's culture',
#  'proven development',
#  'dozen market',
#  'licensed company',
#  'equivalent experience',
#  'such quality',
#  'continuous development',
#  'recruitment process',
#  'development package',
#  'shippable software',
#  'Continuous Integration',
#  'business knowledge',
#  'system house',
#  'work guidance',
#  'injection framework',
#  'lifelong learner',
#  'Recruitment license',
#  'other consumer',
#  'key driver',
#  'bieten dir',
#  'project organization',
#  'corresponding test',
#  'implementation support',
#  'high visibility',
#  'good financing',
#  'German language',
#  'sharing culture',
#  'methodical development',
#  'detailed design',
#  'overall design',
#  'great opportunity',
#  'small scale',
#  'technical lead',
#  'dive experience',
#  'Flexible working',
#  'great chance',
#  'Glassfish application',
#  's team',
#  'x Experience',
#  'various scope',
#  'breakthrough innovation',
#  'various nature',
#  'Intensive training',
#  'other programming',
#  'stable platform',
#  'game room',
#  'unique software',
#  'Competitive pay',
#  'advanced degree',
#  'design work',
#  'product team',
#  'last year',
#  'awesome company',
#  'common coding',
#  'good test',
#  'development company',
#  'career path',
#  'application logic',
#  'Отлични условия',
#  'bug tracking',
#  'equivalent relevant',
#  'accurate time',
#  'available standard',
#  'potential connecting',
#  'mobile development',
#  'Experience building',
#  'Referral program',
#  '… •',
#  'function openPrivacyPopup',
#  'long term',
#  'real business',
#  'friendly attitude',
#  'fast learner',
#  'program code',
#  'trusted partner',
#  'international company',
#  'selection process',
#  'personal growth',
#  'Working time',
#  'record growth',
#  'Practical experience',
#  'private cloud',
#  'concurrency programming',
#  'new world',
#  'attractive salary',
#  'client portfolio',
#  'framework Experience',
#  'enterprise computing',
#  'Bulgarian company',
#  'international provider',
#  'relevant work',
#  'time flexibility',
#  'broad range',
#  'learning culture',
#  'disability status',
#  'primary storage',
#  'other cloud',
#  'specific work',
#  'software application',
#  'delivery network',
#  'advanced solution',
#  'high availability',
#  'motivated professional',
#  'Competitive remuneration',
#  'proactive approach',
#  'salary •',
#  'great usability',
#  'full range',
#  'professional quest',
#  'similar position',
#  'occasional home',
#  'portfolio •',
#  'automotive aftermarket',
#  'outstanding opportunity',
#  'application modernization',
#  'public transport',
#  'Internal tech',
#  'leading company',
#  'main responsibility',
#  'end user',
#  'Constant collaboration',
#  'cloud infrastructure',
#  's estimation',
#  'technical assistance',
#  'bug fixing',
#  're writing',
#  'Good programming',
#  'own software',
#  'university degree',
#  'strong knowledge',
#  'outstanding software',
#  'elegant code',
#  'python code',
#  'own boss',
#  'Profound insight',
#  'excellent command',
#  'international software',
#  'timely manner',
#  'independent survey',
#  'competitive compensation package •',
#  'call support',
#  'full advantage',
#  'application performance',
#  'operational stability',
#  'development phase',
#  'innovative payment',
#  'daily work',
#  'talent pipeline',
#  'product suite',
#  'own time',
#  'robotic arm',
#  'senior developer',
#  'subject matter',
#  'functional programming',
#  'subsidiary company',
#  'international expansion',
#  'health care',
#  'mature understanding',
#  'petrol money',
#  'o Experience',
#  'office building',
#  'load balancing',
#  'technical support',
#  'software cytric',
#  'eProcurement software',
#  'global basis',
#  'phenomenal breadth',
#  'business travel',
#  'competitive remuneration',
#  'unmatched experience',
#  'conceptual design',
#  'insurance plan',
#  'significant portion',
#  'parallel programming',
#  'memory management',
#  'Bulgarian time',
#  'mutual respect',
#  'multiple production',
#  'impeccable quality',
#  'risk management',
#  'technology development',
#  'application lifecycle',
#  'automated build',
#  'perfect environment',
#  'valuable advantage',
#  'great development',
#  'interpersonal communication',
#  'client offer',
#  'applicable software development methodology',
#  'innovative mindset',
#  'open source',
#  'other industry',
#  'cloud environment',
#  'Regular performance',
#  'accelerated business',
#  '’ t',
#  'career progression',
#  'professional setting',
#  'possible mobility',
#  'extensive performance',
#  'technical career',
#  'web development',
#  'solid foundation',
#  'attractive pay',
#  'ace availability',
#  'implement software',
#  'right thing',
#  'other development',
#  'deploy backend',
#  'flagman product',
#  'big plus',
#  'private sector',
#  'jQueryWe offer',
#  'Good knowledge',
#  'internal admin',
#  'extensive business',
#  'software development',
#  'banking sector',
#  'strictest confidentiality',
#  'academic degree',
#  'additional software',
#  'technical experience',
#  'global presence',
#  'corporate bs',
#  'additional language',
#  'Excellent communication',
#  'decision making',
#  'enterprise architecture',
#  't win',
#  'lucrative employee',
#  'utmost satisfaction',
#  'programming background',
#  'Strong communication',
#  'company help',
#  'functional coding',
#  'trading platform',
#  'active listening',
#  'explosive business',
#  'Bulgarian office',
#  'software delivery',
#  'salary package',
#  'genuine passion',
#  'kontinuierlich weiterWir',
#  'positive office',
#  'deep knowledge',
#  'successful path',
#  'culture matter',
#  'excellent equipment',
#  'Flexible bonus',
#  'motivated person',
#  'related field',
#  'high performance',
#  'existing architecture',
#  'pay television',
#  'international working',
#  'general public',
#  'architecture background',
#  'great future',
#  'English resume',
#  'efficient manner',
#  'Constant communication',
#  'global talent',
#  'multiple customer',
#  'Key performance',
#  'immer neue',
#  'remote delivery',
#  'development planning',
#  'competitive salary',
#  'close collaboration',
#  'everyday life',
#  '⦿ Experience',
#  'special protection',
#  'escalated support',
#  'successful candidate',
#  's fun',
#  'capacity plan',
#  'detailed resume',
#  'automation market',
#  'proven experience',
#  'supply chain',
#  'job look',
#  'Good communication',
#  'additional compensation',
#  'business relevant',
#  'Short time',
#  'social gaming',
#  'business software',
#  'licensed Recruitment',
#  'cloud application',
#  'brauchen wir',
#  'срок от',
#  'entire software life cycle',
#  'high calibre',
#  'vSphere management',
#  'blockchain technology',
#  'business card',
#  'big professional',
#  'company performance',
#  'global tech',
#  'technical accountability',
#  'high recognition',
#  'official partner',
#  'digital infrastructure',
#  'effective communication',
#  'technical solution',
#  'curious personality',
#  'interesting stuff',
#  'solution design',
#  'world class software company',
#  'Use company continuous integration',
#  'same code',
#  'various company',
#  'following focus',
#  'positive attitude',
#  'working time',
#  'good programmer',
#  'sport card',
#  'new tea',
#  'table tennis',
#  'edge software',
#  'technical documentation',
#  'нетно старт',
#  'optimized software',
#  'problem solving',
#  'consumer loan',
#  'technical team',
#  'excellent knowledge',
#  'daily routine',
#  'implementation Experience',
#  'flexible schedule',
#  'appropriate implementation',
#  'operational performance',
#  'senior role',
#  'senior position',
#  'platform •',
#  'technical certification',
#  'digital signing',
#  'fun environment',
#  'innovative consultancy',
#  'artifact repository',
#  'future contract',
#  'strong focus',
#  's compute',
#  'production quality',
#  'close supervision',
#  'В',
#  'talented technology',
#  'button bellow',
#  'digital commerce',
#  'technical analysis',
#  'global leader',
#  'obsessive attention',
#  'architectural discussion',
#  'annual vacation',
#  'office fun',
#  'agile team',
#  'different career',
#  'live support',
#  'career development',
#  'job training',
#  'design decision',
#  'art platform',
#  'accurate domain',
#  'great software',
#  'global technology',
#  'functional project',
#  'medical exams',
#  'cryptographic token',
#  'global organization',
#  'success product',
#  'software solution',
#  'Monitoring der',
#  'creative development',
#  'upbeat style',
#  'position interesting',
#  'great number',
#  'annual turnover',
#  'и Spring',
#  'external training',
#  'metro station',
#  'commercial background',
#  'digital supermarket',
#  'technical application',
#  'transparent communication',
#  'custom software',
#  'software developer',
#  'subway intersection',
#  '“ entrepreneur',
#  'team working',
#  'Good experience',
#  'own project',
#  'value innovation',
#  'confident knowledge',
#  'company support service delivery',
#  'broad support',
#  'online grocery',
#  'global scale',
#  'verbal',
#  'test driven',
#  'agile development',
#  'Extensive experience',
#  'strategic management',
#  'vital role',
#  'online casino',
#  'agile development environment •',
#  'system architecture',
#  'company ”',
#  'external employee satisfaction survey',
#  'multi supplier',
#  'rapid delivery',
#  'proven design',
#  'football team',
#  'ongoing project',
#  'debug problem',
#  'commercial software',
#  'peer code',
#  'leading product',
#  'product portfolio',
#  'wohnstWir freuen',
#  'additional “',
#  'Компанията предлага',
#  'online trading',
#  ...}

# %%
#Getting TF-IDF scores 
documents = df_jobs['Text']
kp_tfidfs = score_keyphrases_by_tfidf(documents, candidates)
Counter(kp_tfidfs).most_common(35)
# Out:
# [('senior member', 0.2812052403247175),
#  ('robust design', 0.2812052403247175),
#  ('various entertainment', 0.2812052403247175),
#  ('crisp definition', 0.2812052403247175),
#  ('great opportunity', 0.25932954541363096),
#  ('technical lead', 0.25932954541363096),
#  ('senior developer', 0.25932954541363096),
#  ('office space', 0.24380849286805553),
#  ('depth knowledge', 0.23176942920434854),
#  ('table tennis', 0.23176942920434854),
#  ('full potential', 0.23176942920434854),
#  ('architecture design', 0.21361604473997434),
#  ('working time', 0.2064117454113936),
#  ('verbal', 0.1943726817476866),
#  ('regular team', 0.16901499795473163),
#  ('international company', 0.15434360237222586),
#  ('working environment', 0.1518337497389472),
#  ('problem solving', 0.14493687062731764),
#  ('competitive remuneration', 0.13510023937993812),
#  ('remuneration package', 0.11824696847874398),
#  ('java developer', 0.08151221831038559),
#  ('increased demand', 0.0),
#  ('virtual replication', 0.0),
#  ('new business', 0.0),
#  ('Atlassian apps', 0.0),
#  ('particular department', 0.0),
#  ('clear code', 0.0),
#  ('die wir', 0.0),
#  ('career opportunity', 0.0),
#  ('united team', 0.0),
#  ('encouraging work', 0.0),
#  ('subject line', 0.0),
#  ('project domain', 0.0),
#  ('salary –', 0.0),
#  ('driven organization', 0.0)]

# %%
scores = [('senior member', 0.2812052403247175),
 ('robust design', 0.2812052403247175),
 ('various entertainment', 0.2812052403247175),
 ('crisp definition', 0.2812052403247175),
 ('great opportunity', 0.25932954541363096),
 ('technical lead', 0.25932954541363096),
 ('senior developer', 0.25932954541363096),
 ('office space', 0.24380849286805553),
 ('depth knowledge', 0.23176942920434854),
 ('table tennis', 0.23176942920434854),
 ('full potential', 0.23176942920434854),
 ('architecture design', 0.21361604473997434),
 ('working time', 0.2064117454113936),
 ('verbal', 0.1943726817476866),
 ('regular team', 0.16901499795473163),
 ('international company', 0.15434360237222586),
 ('working environment', 0.1518337497389472),
 ('problem solving', 0.14493687062731764),
 ('competitive remuneration', 0.13510023937993812),
 ('remuneration package', 0.11824696847874398),
 ('java developer', 0.08151221831038559),
 ('increased demand', 0.0),
 ('virtual replication', 0.0),
 ('new business', 0.0),
 ('Atlassian apps', 0.0),
 ('particular department', 0.0),
 ('clear code', 0.0),
 ('die wir', 0.0),
 ('career opportunity', 0.0),
 ('united team', 0.0),
 ('encouraging work', 0.0),
 ('subject line', 0.0),
 ('project domain', 0.0),
 ('salary –', 0.0),
 ('driven organization', 0.0)]
import pandas as pd
pd.DataFrame(scores)
# Out:
#                            0         1
# 0              senior member  0.281205
# 1              robust design  0.281205
# 2      various entertainment  0.281205
# 3           crisp definition  0.281205
# 4          great opportunity  0.259330
# 5             technical lead  0.259330
# 6           senior developer  0.259330
# 7               office space  0.243808
# 8            depth knowledge  0.231769
# 9               table tennis  0.231769
# 10            full potential  0.231769
# 11       architecture design  0.213616
# 12              working time  0.206412
# 13                    verbal  0.194373
# 14              regular team  0.169015
# 15     international company  0.154344
# 16       working environment  0.151834
# 17           problem solving  0.144937
# 18  competitive remuneration  0.135100
# 19      remuneration package  0.118247
# 20            java developer  0.081512
# 21          increased demand  0.000000
# 22       virtual replication  0.000000
# 23              new business  0.000000
# 24            Atlassian apps  0.000000
# 25     particular department  0.000000
# 26                clear code  0.000000
# 27                   die wir  0.000000
# 28        career opportunity  0.000000
# 29               united team  0.000000
# 30          encouraging work  0.000000
# 31              subject line  0.000000
# 32            project domain  0.000000
# 33                  salary –  0.000000
# 34       driven organization  0.000000

# %%
df_jobs["category"] = "BG"
df_jobs.head()
# Out:
#                                            Title  \
# 0            Senior Java Developer - Syncplicity
# 1                         Java Software Engineer
# 2   Senior Java Developer with Oracle Experience
# 3  Senior Software Engineer with Java and Spring
# 4               Java Software Developer Aviation
#
#                                                 Text category
# 0  \n\n\nSenior Java Developer – Syncplicity\nWe ...       BG
# 1  Let us\n                                      ...       BG
# 2  Senior Java Developer with Oracle Experience\n...       BG
# 3  \nSenior Software Engineer with Java and Sprin...       BG
# 4  \n\n\n\n\n\n\n\n\n\n\n\nJava Software Develope...       BG

# %%
df["category"] = "USA"
df_all = pd.concat([df, df_jobs])
df.tail()
# Out:
#                                                  Title  \
# 304  Lead SW Platform Developer (Java, Spring Boot,...
# 305          Software Engineer Java Developer (2+ yrs)
# 306  Full Stack Lead Developer with Angular, Node.j...
# 307  Java developer analytics and big data software...
# 308  Sr Software Developers- Ruby, Java or Javascri...
#
#                                                   Text category
# 304  Lead SW Platform Developer (Java, Spring Boot,...      USA
# 305  Software Engineer Java Developer (2+ yrs)Techn...      USA
# 306  Full Stack Lead Developer with Angular, Node.j...      USA
# 307  Java developer analytics and big data software...      USA
# 308  Sr Software Developers- Ruby, Java or Javascri...      USA

# %%
df_all.tail()
# Out:
#                                   Title  \
# 129  Software Engineer (Python/Java/Go)
# 130       Java Developer - Middle level
# 131               Senior Java developer
# 132                      JAVA DEVELOPER
# 133                Senior Java Engineer
#
#                                                   Text category
# 129  \n\n\n\n\n\n\n\n\n\n\n\n\nSoftware Engineer (P...       BG
# 130  \n\n\n\n\n\n\n\n\n\n\n\n\nJava Developer - Mid...       BG
# 131  \n\n\n\n\n\n\n\n\n\n\nSenior Java developer\n\...       BG
# 132  \n\n\n\n\n\n\n\n\n\n\n\n\nJAVA DEVELOPER\n\n\n...       BG
# 133  \n\n\n\n\n\n\n\n\n\n\n\n\nSenior Java Engineer...       BG

# %% [markdown]
# ## Pointwise Mutual Information
#
# - how likely is it to encounter a __word in a specific category__?
#
# $ \operatorname{PMI}(word, category) = \log\frac{p(word, category)}{p(word)p(category)} $ <br>

# %%
from nltk.tokenize import TweetTokenizer
def all_words(file_list):
    """return list of all words in the files.""" 
    full_text = "\n\n".join(file_list)
    tweet_tok = TweetTokenizer()
    tokens = tweet_tok.tokenize(full_text)  
    tokens_lower = [token.lower() for token in tokens]
    tokens_no_punct = [token for token in tokens_lower if token not in ".!?-/\()[]{},:;`'\""]
    return tokens_no_punct

# %%
# Pontwise mutual information 
def pmi(category):
#     category_files = nltk.corpus.reuters.fileids(category)
#     category_files_words = [_word for _fid in category_files for _word in nltk.corpus.reuters.words(_fid)]
#     total_number_of_words_in_category = len(category_files_words)
#     total_number_of_words = len(nltk.corpus.reuters.words())

    category_files = df_all[df_all["category"]==category]["Text"]
    category_files_words = all_words(category_files)
    total_number_of_words_in_category = len(category_files_words)
    total_words = all_words(df["Text"])
    total_number_of_words = len(total_words)
    
    word_frequencies = Counter(category_files_words)
    word_frequencies_in_category = Counter(total_words)
    
    word_pmis = {}
    for word in set(category_files_words):
        if word in string.punctuation or word in stopwords or len(word)<3:
            continue
        p_wc =  word_frequencies_in_category[word] / total_number_of_words_in_category
        p_w = word_frequencies[word] / total_number_of_words
        p_c = len(df_all[df_all["category"]==category]) / len(df_all)
        word_pmis[word] = p_wc / (p_w * p_c)
    return word_pmis

# %%
pmi_usa = pmi('USA')
Counter(pmi_usa).most_common(20)
# Out:
# [('interfaces', 1.4336569579288028),
#  ('markets', 1.4336569579288028),
#  ('professionals', 1.4336569579288028),
#  ('government', 1.4336569579288028),
#  ('department', 1.4336569579288028),
#  ('make', 1.4336569579288028),
#  ('motivated', 1.4336569579288028),
#  ('strategy', 1.4336569579288028),
#  ('along', 1.4336569579288028),
#  ('sources', 1.4336569579288028),
#  ('leveraging', 1.4336569579288028),
#  ('occasional', 1.4336569579288028),
#  ('top', 1.4336569579288028),
#  ('reviews-los', 1.4336569579288028),
#  ('little', 1.4336569579288028),
#  ('agile', 1.4336569579288028),
#  ('overview', 1.4336569579288028),
#  ('google', 1.4336569579288028),
#  ('critical', 1.4336569579288028),
#  ('fields', 1.4336569579288028)]

# %%
pmi_bg = pmi('BG')
Counter(pmi_bg).most_common(20)
# Out:
# [('ago', 1947.1563755246882),
#  ('save', 1947.1563755246882),
#  ('alternative', 1080.3577309362786),
#  ('report', 659.5207078390073),
#  ('francisco', 439.6804718926715),
#  ('screening', 360.1192436454262),
#  ('disability', 339.1820783172037),
#  ('veteran', 320.3386295218035),
#  ('inc', 309.87004685769233),
#  ('religion', 301.4951807264033),
#  ('origin', 301.4951807264033),
#  ('san', 266.94885793483627),
#  ('type', 251.24598393866944),
#  ('methods', 236.17122490234928),
#  ('preferred', 224.02766901198024),
#  ('status', 211.04662650848232),
#  ('marital', 200.99678715093552),
#  ('gender', 194.7156375524688),
#  ('instructions', 182.15333835553537),
#  ("bachelor's", 179.01276355630196)]
